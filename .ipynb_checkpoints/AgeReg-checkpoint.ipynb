# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import os

# %% [markdown]
# Format of the file: age_gender_ethnicity_datetime
# ## Load and Visualize data

# %%
path = "UTKFace/"
files = os.listdir(path)
#la lista dei file viene caricata in modo arbitratrio, quindi la ordino per conformarla
files.sort()
size = len(files)
print("Total samples:",size)
#print(files[0])
# Out:
# Total samples: 23708

# %%
import cv2
images = []
ages = []
genders = []
ethnicities = [] 
#prova = cv2.imread(path+files[43])
#cv2.imshow('prova',prova)
#cv2.waitKey()
#cv2.destroyAllWindows()

for file in files:
    image = cv2.imread(path + file, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, dsize=(64,64))
    image = image.reshape((-1,image.shape[0],image.shape[1],3))
    images.append(image)
    split_var = file.split('_')
    ages.append(int(split_var[0]))
    genders.append(int(split_var[1]))
    ethnicities.append(int(split_var[2]))

# %%
import matplotlib.pyplot as plt
x_ages = list(set(ages))
y_ages = [ages.count(i) for i in x_ages]
plt.bar(x_ages,y_ages)
plt.show()
print("Max value:",max(ages))
# Out:
# Max value: 116

# %%
x_genders = list(set(genders))
y_genders = [genders.count(i) for i in x_genders]
plt.bar(x_genders,y_genders)
plt.show()

# %%
x_ethnicities = list(set(ethnicities))
y_ethnicities = [ethnicities.count(i) for i in x_ethnicities]
plt.bar(x_ethnicities,y_ethnicities)
plt.show()

# %%
def display(img):
    plt.imshow(img, interpolation='bicubic')
    plt.xticks([]), plt.yticks([]) 
    plt.show()

X = np.squeeze(images)
idx = 14
sample = images[idx]
print("Age:",ages[idx])
print("Gender:",genders[idx])
print("Ethnicity:",ethnicities[idx])
display(X[1])
# Out:
# Age: 105
# Gender: 0
# Ethnicity: 0

# %% [markdown]
# # def display(img):
#    # plt.imshow(img[:,:])
#   #  plt.show()
#
#
# idx = 14
# sample = images[idx]
# print("Age:",ages[idx])
# print("Gender:",genders[idx])
# print("Ethnicity:",ethnicities[idx])
# display(sample)

# %%
# pre processing
target = np.zeros(size,dtype='int32')
features = []

for i in range(size):
    target[i] = int(ages[i])
    
    featElement = np.array([images[i],int(genders[i]),int(ethnicities[i])])
    features.append(featElement)
    
    #CAPIRE SIGNIFICATO
#features[i] = features[i] / 255

features = np.asarray(features)

# %%
idx=1
display(features[idx][0])
print("Name:",files[idx])
print("Age:",target[idx])
print("Sex:",features[idx][1])
print("Ethnicity:",features[idx][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-3af4b13846ba> in <module>
#       1 idx=1
# ----> 2 display(features[idx][0])
#       3 print("Name:",files[idx])
#       4 print("Age:",target[idx])
#       5 print("Sex:",features[idx][1])
#
# <ipython-input-128-3d5f102ab93d> in display(img)
#       1 def display(img):
# ----> 2     plt.imshow(img, interpolation='bicubic')
#       3     plt.xticks([]), plt.yticks([])
#       4     plt.show()
#       5
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677                               resample=resample, **kwargs)
#    5678
# -> 5679         im.set_data(X)
#    5680         im.set_alpha(alpha)
#    5681         if im.get_clip_path() is None:
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (1, 64, 64, 3) for image data

# %%
#Creazione CSV
import csv

with open('dataset.csv', 'w') as csvfile:
    filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow(["ID", "Image", "Age", "Sex", "Ethnicity"])
   
    for i in range(size):
        arr = np.array(images[i])
        flat_arr = arr.ravel()
        filewriter.writerow([i, flat_arr, ages[i], genders[i], ethnicities[i]])

# %%
from sklearn.model_selection import train_test_split

#oltre ai soliti primi 4 parametri, inserisco name_train e name_test per inserire i nomi dei file per poterli dividere in cartelle
x_train, x_test, y_train, y_test, name_train, name_test = train_test_split(features, target, files, test_size=0.3,random_state=42,shuffle=True)
print("Samples in Training:",x_train.shape[0])
print("Samples in Testing:",x_test.shape[0])
# Out:
# Samples in Training: 16595
# Samples in Testing: 7113

# %%
idx=1
display(x_train[idx][0])
print(y_train[idx])
print(name_train[idx])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-10a9f186ccc6> in <module>
#       1 idx=1
# ----> 2 display(x_train[idx][0])
#       3 print(y_train[idx])
#       4 print(name_train[idx])
#
# <ipython-input-128-3d5f102ab93d> in display(img)
#       1 def display(img):
# ----> 2     plt.imshow(img, interpolation='bicubic')
#       3     plt.xticks([]), plt.yticks([])
#       4     plt.show()
#       5
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677                               resample=resample, **kwargs)
#    5678
# -> 5679         im.set_data(X)
#    5680         im.set_alpha(alpha)
#    5681         if im.get_clip_path() is None:
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (1, 64, 64, 3) for image data

# %%
idx=1
display(x_test[idx][0])
print(y_test[idx])
print(name_test[idx])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-0babc2127dd6> in <module>
#       1 idx=1
# ----> 2 display(x_test[idx][0])
#       3 print(y_test[idx])
#       4 print(name_test[idx])
#
# <ipython-input-128-3d5f102ab93d> in display(img)
#       1 def display(img):
# ----> 2     plt.imshow(img, interpolation='bicubic')
#       3     plt.xticks([]), plt.yticks([])
#       4     plt.show()
#       5
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677                               resample=resample, **kwargs)
#    5678
# -> 5679         im.set_data(X)
#    5680         im.set_alpha(alpha)
#    5681         if im.get_clip_path() is None:
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (1, 64, 64, 3) for image data

# %%
from pathlib import Path
import shutil
from collections import Counter

#controllo se le cartelle test e training sono già presenti
print("Cartella training?",os.path.isdir("training"))
print("Cartella test?",os.path.isdir("test"))



#controllo se i dati sono già presenti nelle cartelle (non è la prima esecuzione del codice)
firstExec = True
#DA MIGLIORARE EFFICIENZA
if((os.path.isdir("training")) and (os.path.isdir("test"))):
    trElements = os.listdir("training/")
    teElements = os.listdir("test/")
    if((Counter(name_train) == Counter(trElements)) and (Counter(name_test) == Counter(teElements))):
        firstExec = False

print("Prima esecuzione?",firstExec)
# Out:
# Cartella training? True
# Cartella test? True
# Prima esecuzione? False

# %%
#se è la prima esecuzione creo le cartelle e vi inserisco i file        
if(firstExec):
    #creo la cartella dove inserire le immagini di training
    Path("training").mkdir(parents=True, exist_ok=True)
    
    #copio le immagini di training
    for i in range(0,x_train.shape[0]):
        shutil.copy(path+name_train[i],"training/"+name_train[i])
    trElements = os.listdir("training/")
    #print(set(name_train).symmetric_difference(set(trElements)))
    assert Counter(name_train) == Counter(trElements),set(name_train).symmetric_difference(set(trElements))
    
    #creo la cartella dove inserire le immagini di test
    Path("test").mkdir(parents=True, exist_ok=True)
    #copio le immagini di test
    for i in range(0,x_test.shape[0]):
        shutil.copy(path+name_test[i],"test/"+name_test[i])
    teElements = os.listdir("test/")
    assert Counter(name_test) == Counter(teElements),set(name_test).symmetric_difference(set(teElements))

# %%
idx=50
display(x_train[idx][0])
print(y_train[idx])
print(name_train[idx])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-305d45f2232b> in <module>
#       1 idx=50
# ----> 2 display(x_train[idx][0])
#       3 print(y_train[idx])
#       4 print(name_train[idx])
#
# <ipython-input-128-3d5f102ab93d> in display(img)
#       1 def display(img):
# ----> 2     plt.imshow(img, interpolation='bicubic')
#       3     plt.xticks([]), plt.yticks([])
#       4     plt.show()
#       5
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5677                               resample=resample, **kwargs)
#    5678
# -> 5679         im.set_data(X)
#    5680         im.set_alpha(alpha)
#    5681         if im.get_clip_path() is None:
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (1, 64, 64, 3) for image data

# %%
#Utility per stampare lista file testing
f= open("test.txt","w+")
for i in range(0,len(os.listdir("test/"))):
        f.write(name_test[i]+"\n")
f.close()

# %% [markdown]
# ## Build Model

# %%
import keras 
from keras.layers import *
from keras.models import *
from keras import backend as K

def build_one_model(optimizer):
    # we can build it
    inputs = Input(shape=(features[0][0].shape))
    conv1 = Conv2D(32, kernel_size=(3, 3),activation='relu')(inputs)
    conv2 = Conv2D(64, kernel_size=(3, 3),activation='relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(128, kernel_size=(3, 3),activation='relu')(pool1)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv3)
    x = Dropout(0.25)(pool2)
    flat = Flatten()(x)

    dropout = Dropout(0.5)
    age_model = Dense(128, activation='relu')(flat)
    age_model = dropout(age_model)
    age_model = Dense(64, activation='relu')(age_model)
    age_model = dropout(age_model)
    age_model = Dense(32, activation='relu')(age_model)
    age_model = dropout(age_model)
    age_model = Dense(1, activation='relu')(age_model)
    
    model = Model(inputs=inputs, outputs=[age_model])
    model.compile(optimizer = optimizer, loss =['mse'],metrics=['accuracy'])
    return model

#model=build_one_model()

# %%
print(x_train[:,[0]].shape)
# Out:
# (16595, 1)

# %% [markdown]
# ## GridSearchCV

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense 

clasf = KerasRegressor(build_fn = build_one_model)

parameters = {'batch_size': [25, 32, 100, 80],
             'nb_epoch' : [100, 500], 
             'optimizer' : ['adam', 'rmsprop'] }

# specifichiamo di voler massimizzare l'accuracy e di utilizzare una cross-validation = 10.
grid_search = GridSearchCV(estimator = clasf, param_grid = parameters, scoring = 'accuracy', cv = 10 )

# %%
#x_reshaped = x_train[:,[0]].reshape([size,64, 64,3])

# grid search proverà tutte le conbinazioni e ci restituirà quella ottimale.
grid_search = grid_search.fit(x_train[:,[0]], y_train)
# Out:
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1966: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1967: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1968: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1969: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1970: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1971: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1972: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1973: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1974: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1975: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1976: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1977: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1978: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1979: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1980: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1981: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1982: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1983: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1984: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1985: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1986: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1987: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1988: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1989: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1990: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1991: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1992: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1993: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1994: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1995: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1996: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1997: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1998: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_1999: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2000: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2001: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2002: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2003: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2004: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2005: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2006: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2007: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2008: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2009: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2010: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2011: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2012: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2013: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2014: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2015: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2016: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2017: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2018: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2019: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2020: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2021: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2022: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2023: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2024: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2025: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2026: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2027: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2028: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2029: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2030: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2031: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2032: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2033: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2034: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2035: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2036: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2037: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2038: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2039: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2040: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2041: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2042: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2043: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2044: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2045: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2046: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2047: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2048: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2049: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2050: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2051: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2052: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2053: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2054: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2055: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2056: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2057: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2058: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2059: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2060: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2061: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2062: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2063: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2064: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2065: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2066: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2067: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2068: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2069: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2070: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2071: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2072: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2073: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2074: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2075: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2076: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2077: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2078: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2079: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2080: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2081: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2082: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2083: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2084: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2085: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2086: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2087: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2088: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2089: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2090: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2091: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2092: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2093: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2094: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2095: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2096: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2097: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2098: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2099: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2100: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2101: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2102: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2103: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2104: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2105: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2106: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2107: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2108: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2109: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2110: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2111: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2112: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2113: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2114: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2115: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2116: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2117: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2118: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2119: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2120: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2121: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2122: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2123: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2124: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# /Users/domenicotrotta/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input 0 is incompatible with layer conv2d_2125: expected ndim=4, found ndim=5
#
#   FitFailedWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-78cac267c366> in <module>
#       2
#       3 # grid search proverà tutte le conbinazioni e ci restituirà quella ottimale.
# ----> 4 grid_search = grid_search.fit(x_train[:,[0]], y_train)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     737             refit_start_time = time.time()
#     738             if y is not None:
# --> 739                 self.best_estimator_.fit(X, y, **fit_params)
#     740             else:
#     741                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     140                 **self.filter_sk_params(self.build_fn.__call__))
#     141         else:
# --> 142             self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#     143
#     144         if (losses.is_categorical_crossentropy(self.model.loss) and
#
# <ipython-input-139-40ff0d342487> in build_one_model(optimizer)
#       7     # we can build it
#       8     inputs = Input(shape=(features[0][0].shape))
# ----> 9     conv1 = Conv2D(32, kernel_size=(3, 3),activation='relu')(inputs)
#      10     conv2 = Conv2D(64, kernel_size=(3, 3),activation='relu')(conv1)
#      11     pool1 = MaxPooling2D(pool_size=(2, 2))(conv2)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     444                 # Raise exceptions in case the input is not compatible
#     445                 # with the input_spec specified in the layer constructor.
# --> 446                 self.assert_input_compatibility(inputs)
#     447
#     448                 # Collect input shapes to build layer.
#
# ~/opt/anaconda3/envs/fvab/lib/python3.7/site-packages/keras/engine/base_layer.py in assert_input_compatibility(self, inputs)
#     340                                      self.name + ': expected ndim=' +
#     341                                      str(spec.ndim) + ', found ndim=' +
# --> 342                                      str(K.ndim(x)))
#     343             if spec.max_ndim is not None:
#     344                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer conv2d_2126: expected ndim=4, found ndim=5

# %%
best_parameters = grid_search.best_params_
best_parameters

# %% [markdown]
# ## K-FOLD VALIDATION

# %%
from keras.wrappers.scikit_learn import KerasRegressor 
from sklearn.model_selection import cross_val_score
# Out:
# Using TensorFlow backend.

# %%
clasf = KerasRegressor(build_fn = build_one_model("adam"), batch_size =80  , nb_epoch = 100) 
accuracies = cross_val_score( estimator = clasf, X = x_train[:,[0]], y = y_train, cv = 10, n_jobs = -1  ) # cv = 10
# n_jobs = -1 use all the CPU to do parallel computation 
#cv indica il numero di fold in cui è stato suddiviso il training data.

# %%
accuracies # this is the relevant result 
#Abbiamo 10 valori di accuracy poiché è stato effettuato il test su 10 fold diversi.

# %%
# let's compute the mean of the accuracies 
mean = accuracies.mean()
mean

# %%
variance = accuracies.std()
variance

# %%
#image = x_train[0][0].reshape(-1,64,64,3)
#print(image.shape)
# Out:
# (1, 64, 64, 3)
